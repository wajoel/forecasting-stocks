# %%
from indices import load_data, plot_data, clean_data, check_stationarity, plot_acf_pacf, rolling_statistics, decompose_time_series

# %%
file_path = r"C:\Users\BRAILER\Downloads\S&P 500 Historical Data.csv"

    # Load and clean the data
df = load_data(file_path)
df = clean_data(df)
plot_data(df)

# %%
# Time Series Analysis
check_stationarity(df)  # ADF test
# Out:
# ADF Test Results:
# ADF Statistic: 1.2915708529132843
# p-value: 0.9965613210601335
# Non-Stationary

# %%
plot_acf_pacf(df)  # Autocorrelation and Partial Autocorrelation

# %%
rolling_statistics(df)  # Rolling mean and standard deviation

# %%
decompose_time_series(df)  # STL decomposition

# %%
# from indices import load_data, plot_data, clean_data, check_stationarity, plot_acf_pacf, rolling_statistics, decompose_time_series
# if __name__ == "__main__":
#     file_path = r"C:\Users\BRAILER\Downloads\S&P 500 Historical Data.csv"

#     # Load and clean the data
#     df = load_data(file_path)
#     df = clean_data(df)
#     plot_data(df)

#     # Time Series Analysis
#     check_stationarity(df)  # ADF test
#     plot_acf_pacf(df)  # Autocorrelation and Partial Autocorrelation
#     rolling_statistics(df)  # Rolling mean and standard deviation
#     decompose_time_series(df)  # STL decomposition
